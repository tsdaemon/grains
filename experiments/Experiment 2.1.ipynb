# %% [markdown]
# # Non-derivative curve fitting with adaptive threshold
#
# It's the same as 2, but I want to try adaptive threshold instead of usual.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 9]

img = cv2.imread('../example_data/Snap-05.jpg')
plt.imshow(img)
plt.show()

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
clahe = cv2.createCLAHE(clipLimit=20.0, tileGridSize=(64, 64))
img_cl = clahe.apply(img_gray)
plt.imshow(img_cl, cmap='gray')
plt.show()

# %%
img_bl = cv2.blur(img_cl, (10, 10))
plt.imshow(img_bl, cmap='gray')
plt.show()

# %%
img_tr = cv2.adaptiveThreshold(img_bl, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 1001, 2)
plt.imshow(img_tr, cmap='gray')
plt.show()

# %%
contours, hierarchy = cv2.findContours(img_tr, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img_contours = img.copy()
img_contours = cv2.drawContours(img_contours, contours, -1, (0,0,255), 3)
plt.imshow(img_contours)
plt.show()

# %% [markdown]
#  Adaptive threshold have interesting results, but it leaves a lot of noise dots.
